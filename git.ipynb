# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd drive/MyDrive/Colab_Notebooks/CPSC532S/final_project/code
# Out:
# /content/drive/MyDrive/Colab_Notebooks/CPSC532S/final_project/code

# %%
# !git --version

# %%
# !git config --global user.email "shenning1997@gmail.com"
# !git config --global user.name "nshen7"

# %%
# !ls
# Out:
# eda.ipynb  git.ipynb  resources  run  train

# %%
# !git init

# %%
# !git remote add origin https://nshen7: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@github.com/nshen7/multimodal-cell-matching.git

# %%
# !git pull

# %%
# !git add .

# %%
# Remember to change message!!!
# !git commit -m ""
# Out:
# [master dbaa823] finished EDA
#  8 files changed, 13 insertions(+), 69 deletions(-)
#  delete mode 100644 EDA.ipynb
#  create mode 100644 eda.ipynb
#  rewrite git.ipynb (70%)
#  create mode 100644 resources/config.py
#  create mode 100644 resources/models.ipynb
#  delete mode 100644 resources/preprocessing.py
#  create mode 100644 resources/utils.ipynb
#  delete mode 100644 split_chromosome.py

# %%
# !git push -u -f origin master
# Out:
# Counting objects: 8, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 13.63 KiB | 1.36 MiB/s, done.
# Total 8 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/nshen7/multimodal-cell-matching.git
#    1de8055..dbaa823  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
